# %%
import pandas as pd
import numpy as np

# %%
wetchem_df = pd.read_csv("inputFiles/uncleaned_wetchem_20200916-20221107.csv")
hv_outliers_df = pd.read_csv("outputFiles/hv_outliers.csv")
lv_outliers_df = pd.read_csv("outputFiles/lv_outliers.csv")
resid_outliers_df = pd.read_csv("outputFiles/residual_outliers_filtered_out.csv")
cooks_outliers_df = pd.read_csv("outputFiles/outliers_cooks_distance.csv")
# Out:
# C:\Users\Tsuma Thomas\AppData\Local\Temp\ipykernel_3080\161898168.py:1: DtypeWarning: Columns (5,13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   wetchem_df = pd.read_csv("inputFiles/uncleaned_wetchem_20200916-20221107.csv")

# %%
hv_outliers_df
# Out:
#          sample_code  aluminium    boron   cec  calcium  clay  copper  \
# 0        CA040CM0001        NaN    7.980   NaN     2.20   NaN    7.62
# 1        CC176SA6046        NaN    3.330   NaN      NaN   NaN    1.03
# 2        CD018PA0028        NaN   43.900   NaN     1.10   NaN   14.20
# 3        CD018PA0031        NaN   47.200   NaN     1.60   NaN   18.30
# 4        CD162AF0014        NaN  336.000   NaN     0.66   NaN    8.82
# ...              ...        ...      ...   ...      ...   ...     ...
# 1181     CT240CM0009        NaN    5.100   NaN     0.11   NaN   45.50
# 1182     CV083FA0002     2248.0    0.010   NaN     3.64   NaN    0.10
# 1183    CW017SA22112     2240.0    0.020  0.20     4.03   NaN    0.64
# 1184    CW017SA22117     2250.0    0.049  2.69    60.10   NaN    4.80
# 1185  I38-1-25SA0015        NaN   13.400   NaN      NaN   NaN   13.90
#
#       ec_(salts)  exchangeable_acidity    iron  ...  manganese  \
# 0           5.31                   NaN   990.0  ...      43.80
# 1         439.00                   NaN   180.0  ...     119.00
# 2            NaN                   NaN   226.0  ...      69.80
# 3            NaN                   NaN   210.0  ...      59.30
# 4            NaN                   NaN   853.0  ...    1240.00
# ...          ...                   ...     ...  ...        ...
# 1181        9.94                   NaN   336.0  ...      32.00
# 1182         NaN                   NaN  1695.0  ...     165.40
# 1183       57.70                  0.65   332.0  ...       0.53
# 1184       94.00                  1.00   176.0  ...      23.70
# 1185         NaN                   NaN   367.0  ...      74.80
#
#       organic_carbon    ph  phosphorus  sand  silt   sodium  sulphur  \
# 0                NaN   NaN       0.056   NaN   NaN      NaN     0.39
# 1               6.00  6.57      95.500   NaN   NaN    12.60    29.20
# 2                NaN   NaN       1.510   NaN   NaN   115.00     0.53
# 3                NaN   NaN       1.170   NaN   NaN   125.00     0.53
# 4                NaN   NaN       1.510   NaN   NaN  1600.00     0.96
# ...              ...   ...         ...   ...   ...      ...      ...
# 1181             NaN  7.27       0.480   NaN   NaN  1120.00     0.43
# 1182             NaN   NaN      10.010   NaN   NaN     0.22     0.08
# 1183             NaN  5.04       1.290   NaN   NaN     2.14    10.50
# 1184             NaN  4.75       3.210   NaN   NaN     8.14    22.80
# 1185            6.85  5.92         NaN   NaN   NaN   198.00      NaN
#
#       total_nitrogen    zinc
# 0              11.60   27.40
# 1               0.24   65.90
# 2               7.98   51.90
# 3               8.33   48.60
# 4                NaN  476.00
# ...              ...     ...
# 1181            7.79  128.00
# 1182             NaN   31.88
# 1183             NaN    1.07
# 1184             NaN    7.86
# 1185            2.87   39.90
#
# [1186 rows x 21 columns]

# %%
lv_outliers_df
# Out:
#         sample_code  aluminium    boron   cec  calcium  clay  copper  \
# 0       CA040CM0001        NaN    7.980   NaN     2.20   NaN    7.62
# 1       CC176SA6046        NaN    3.330   NaN      NaN   NaN    1.03
# 2       CD018PA0028        NaN   43.900   NaN     1.10   NaN   14.20
# 3       CD018PA0031        NaN   47.200   NaN     1.60   NaN   18.30
# 4       CD162AF0014        NaN  336.000   NaN     0.66   NaN    8.82
# ..              ...        ...      ...   ...      ...   ...     ...
# 144     CT042SA6302        NaN      NaN   NaN      NaN  1.01     NaN
# 145     CT042SA6304        NaN      NaN   NaN      NaN  1.01     NaN
# 146     CT240CM0009        NaN    5.100   NaN     0.11   NaN   45.50
# 147    CW017SA22117     2250.0    0.049  2.69    60.10   NaN    4.80
# 148  I38-1-25SA0015        NaN   13.400   NaN      NaN   NaN   13.90
#
#      ec_(salts)  exchangeable_acidity   iron  ...  manganese  organic_carbon  \
# 0          5.31                   NaN  990.0  ...       43.8             NaN
# 1        439.00                   NaN  180.0  ...      119.0            6.00
# 2           NaN                   NaN  226.0  ...       69.8             NaN
# 3           NaN                   NaN  210.0  ...       59.3             NaN
# 4           NaN                   NaN  853.0  ...     1240.0             NaN
# ..          ...                   ...    ...  ...        ...             ...
# 144         NaN                   NaN    NaN  ...        NaN            0.14
# 145         NaN                   NaN    NaN  ...        NaN            0.21
# 146        9.94                   NaN  336.0  ...       32.0             NaN
# 147       94.00                   1.0  176.0  ...       23.7             NaN
# 148         NaN                   NaN  367.0  ...       74.8            6.85
#
#        ph  phosphorus  sand  silt   sodium  sulphur  total_nitrogen    zinc
# 0     NaN       0.056   NaN   NaN      NaN     0.39          11.600   27.40
# 1    6.57      95.500   NaN   NaN    12.60    29.20           0.240   65.90
# 2     NaN       1.510   NaN   NaN   115.00     0.53           7.980   51.90
# 3     NaN       1.170   NaN   NaN   125.00     0.53           8.330   48.60
# 4     NaN       1.510   NaN   NaN  1600.00     0.96             NaN  476.00
# ..    ...         ...   ...   ...      ...      ...             ...     ...
# 144   NaN         NaN  98.8  0.14      NaN      NaN           0.012     NaN
# 145   NaN         NaN  98.8  0.14      NaN      NaN           0.016     NaN
# 146  7.27       0.480   NaN   NaN  1120.00     0.43           7.790  128.00
# 147  4.75       3.210   NaN   NaN     8.14    22.80             NaN    7.86
# 148  5.92         NaN   NaN   NaN   198.00      NaN           2.870   39.90
#
# [149 rows x 21 columns]

# %%
resid_outliers_df
# Out:
#            sample_code  index  aluminium  boron   cec  calcium  clay  copper  \
# 0     AGD207-408SA0706    645        NaN   0.83  15.0   1820.0   NaN    5.08
# 1     AGD207-410SA0001    741        NaN   0.44  15.7   1280.0   NaN    1.32
# 2     AGD207-410SA0002    742        NaN   0.34  13.3    955.0   NaN    1.16
# 3     AGD207-411SA0001    743        NaN   0.56  17.3   1540.0   NaN    1.11
# 4     AGD207-411SA0002    744        NaN   0.49  15.5   1470.0   NaN    1.06
# ...                ...    ...        ...    ...   ...      ...   ...     ...
# 9135    FA913-19SA0001  96294        NaN    NaN   NaN      NaN   NaN     NaN
# 9136    FA913-21SA0001  96297        NaN    NaN  31.3      NaN   NaN     NaN
# 9137    FA913-22SA0001  96298        NaN    NaN  21.4   2530.0   NaN     NaN
# 9138   I48-1-108SA0001  97716        NaN   0.37   NaN      NaN   NaN    1.56
# 9139   I48-1-109SA0001  97717        NaN   3.52  29.2      NaN   NaN    0.75
#
#       ec_(salts)  exchangeable_acidity  ...  manganese  organic_carbon    ph  \
# 0            NaN                   NaN  ...      202.0            2.87  6.48
# 1            NaN                   NaN  ...      201.0            2.45  5.40
# 2            NaN                   NaN  ...      192.0            2.61  5.31
# 3            NaN                   NaN  ...      232.0            3.15  5.51
# 4            NaN                   NaN  ...      197.0            2.92  5.63
# ...          ...                   ...  ...        ...             ...   ...
# 9135         NaN                   NaN  ...        NaN             NaN  7.53
# 9136         NaN                   NaN  ...        NaN             NaN  6.82
# 9137         NaN                   NaN  ...        NaN             NaN  6.55
# 9138       136.0                   NaN  ...       26.8             NaN  7.17
# 9139       460.0                   NaN  ...       17.6             NaN  7.48
#
#       phosphorus  sand  silt  sodium  sulphur  total_nitrogen  zinc
# 0          84.00   NaN   NaN    6.34     16.8            0.19  8.64
# 1           2.34   NaN   NaN    4.74     17.9            0.17  3.42
# 2           1.36   NaN   NaN    5.34     14.5            0.18  2.23
# 3           2.87   NaN   NaN    5.81     16.8            0.22  4.30
# 4           1.93   NaN   NaN    7.21     16.9            0.20  3.39
# ...          ...   ...   ...     ...      ...             ...   ...
# 9135         NaN   NaN   NaN     NaN      NaN            0.20   NaN
# 9136      316.00   NaN   NaN   55.70      NaN            0.19   NaN
# 9137       30.80   NaN   NaN   47.40      NaN            0.14   NaN
# 9138      165.00   NaN   NaN   36.70     61.6            0.19  0.66
# 9139         NaN   NaN   NaN  101.00    183.0            0.81  0.50
#
# [9140 rows x 22 columns]

# %%
cooks_outliers_df
# Out:
#            sample_code  aluminium  boron   cec  calcium  clay  copper  \
# 0      AGD103-32SA0001        NaN    NaN   NaN   3240.0   NaN     NaN
# 1      AGD103-33SA0001        NaN    NaN  45.0   4230.0   NaN     NaN
# 2      AGD103-34SA0001        NaN    NaN  49.0   5120.0   NaN     NaN
# 3      AGD103-34SA0002        NaN    NaN  47.9   5380.0   NaN     NaN
# 4      AGD103-37SA0001        NaN    NaN  37.7   3730.0   NaN     NaN
# ...                ...        ...    ...   ...      ...   ...     ...
# 16426    I38-1-9SA0003        NaN    NaN   NaN   4080.0   NaN     NaN
# 16427    I38-1-9SA0005        NaN    NaN   NaN   3640.0   NaN     NaN
# 16428  I48-1-108SA0001        NaN    NaN  43.8   8010.0   NaN     NaN
# 16429  I48-1-109SA0001        NaN    NaN   NaN   4990.0   NaN     NaN
# 16430           MN0001        NaN    NaN   NaN      NaN   NaN  1940.0
#
#        ec_(salts)  exchangeable_acidity    iron  ...  manganese  \
# 0             NaN                   NaN     NaN  ...        NaN
# 1             NaN                   NaN     NaN  ...        NaN
# 2             NaN                   NaN     NaN  ...        NaN
# 3             NaN                   NaN     NaN  ...        NaN
# 4             NaN                   NaN     NaN  ...        NaN
# ...           ...                   ...     ...  ...        ...
# 16426         NaN                   NaN     NaN  ...        NaN
# 16427         NaN                   NaN     NaN  ...        NaN
# 16428         NaN                   NaN     NaN  ...        NaN
# 16429         NaN                   NaN     NaN  ...        NaN
# 16430         NaN                   NaN  8450.0  ...     3890.0
#
#        organic_carbon  ph  phosphorus  sand  silt  sodium  sulphur  \
# 0                 NaN NaN         NaN   NaN   NaN     NaN      NaN
# 1                 NaN NaN         NaN   NaN   NaN     NaN      NaN
# 2                 NaN NaN         NaN   NaN   NaN     NaN      NaN
# 3                 NaN NaN         NaN   NaN   NaN     NaN      NaN
# 4                 NaN NaN         NaN   NaN   NaN     NaN      NaN
# ...               ...  ..         ...   ...   ...     ...      ...
# 16426             NaN NaN         NaN   NaN   NaN     NaN      NaN
# 16427             NaN NaN         NaN   NaN   NaN     NaN      NaN
# 16428             NaN NaN         NaN   NaN   NaN     NaN      NaN
# 16429             NaN NaN         NaN   NaN   NaN     NaN      NaN
# 16430             NaN NaN         NaN   NaN   NaN     NaN      NaN
#
#        total_nitrogen    zinc
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 16426             NaN     NaN
# 16427             NaN     NaN
# 16428             NaN     NaN
# 16429             NaN     NaN
# 16430             NaN  6130.0
#
# [16431 rows x 21 columns]

# %%
wetchem_df = wetchem_df.rename(columns={"Unnamed: 0":"sample_code"})

# %%
# Handle the HV Outliers
hv_outliers_df_2 = hv_outliers_df.set_index("sample_code").isna()

# %%
hv_outliers_df_2.replace(True, np.nan, inplace=True)
hv_outliers_df_2.replace(False, 1, inplace=True)

# %%
hv_outliers_df_2
# Out:
#                 aluminium  boron  cec  calcium  clay  copper  ec_(salts)  \
# sample_code
# CA040CM0001           NaN    1.0  NaN      1.0   NaN     1.0         1.0
# CC176SA6046           NaN    1.0  NaN      NaN   NaN     1.0         1.0
# CD018PA0028           NaN    1.0  NaN      1.0   NaN     1.0         NaN
# CD018PA0031           NaN    1.0  NaN      1.0   NaN     1.0         NaN
# CD162AF0014           NaN    1.0  NaN      1.0   NaN     1.0         NaN
# ...                   ...    ...  ...      ...   ...     ...         ...
# CT240CM0009           NaN    1.0  NaN      1.0   NaN     1.0         1.0
# CV083FA0002           1.0    1.0  NaN      1.0   NaN     1.0         NaN
# CW017SA22112          1.0    1.0  1.0      1.0   NaN     1.0         1.0
# CW017SA22117          1.0    1.0  1.0      1.0   NaN     1.0         1.0
# I38-1-25SA0015        NaN    1.0  NaN      NaN   NaN     1.0         NaN
#
#                 exchangeable_acidity  iron  magnesium  manganese  \
# sample_code
# CA040CM0001                      NaN   1.0        1.0        1.0
# CC176SA6046                      NaN   1.0        1.0        1.0
# CD018PA0028                      NaN   1.0        1.0        1.0
# CD018PA0031                      NaN   1.0        1.0        1.0
# CD162AF0014                      NaN   1.0        1.0        1.0
# ...                              ...   ...        ...        ...
# CT240CM0009                      NaN   1.0        1.0        1.0
# CV083FA0002                      NaN   1.0        1.0        1.0
# CW017SA22112                     1.0   1.0        1.0        1.0
# CW017SA22117                     1.0   1.0        1.0        1.0
# I38-1-25SA0015                   NaN   1.0        NaN        1.0
#
#                 organic_carbon   ph  phosphorus  sand  silt  sodium  sulphur  \
# sample_code
# CA040CM0001                NaN  NaN         1.0   NaN   NaN     NaN      1.0
# CC176SA6046                1.0  1.0         1.0   NaN   NaN     1.0      1.0
# CD018PA0028                NaN  NaN         1.0   NaN   NaN     1.0      1.0
# CD018PA0031                NaN  NaN         1.0   NaN   NaN     1.0      1.0
# CD162AF0014                NaN  NaN         1.0   NaN   NaN     1.0      1.0
# ...                        ...  ...         ...   ...   ...     ...      ...
# CT240CM0009                NaN  1.0         1.0   NaN   NaN     1.0      1.0
# CV083FA0002                NaN  NaN         1.0   NaN   NaN     1.0      1.0
# CW017SA22112               NaN  1.0         1.0   NaN   NaN     1.0      1.0
# CW017SA22117               NaN  1.0         1.0   NaN   NaN     1.0      1.0
# I38-1-25SA0015             1.0  1.0         NaN   NaN   NaN     1.0      NaN
#
#                 total_nitrogen  zinc
# sample_code
# CA040CM0001                1.0   1.0
# CC176SA6046                1.0   1.0
# CD018PA0028                1.0   1.0
# CD018PA0031                1.0   1.0
# CD162AF0014                NaN   1.0
# ...                        ...   ...
# CT240CM0009                1.0   1.0
# CV083FA0002                NaN   1.0
# CW017SA22112               NaN   1.0
# CW017SA22117               NaN   1.0
# I38-1-25SA0015             1.0   1.0
#
# [1186 rows x 20 columns]

# %%
# Handle lv outliers
lv_outliers_df_2 = lv_outliers_df.set_index("sample_code").isna()   

lv_outliers_df_2.replace(True, np.nan, inplace=True)
lv_outliers_df_2.replace(False, 2, inplace=True)

# %%
lv_outliers_df_2
# Out:
#                 aluminium  boron  cec  calcium  clay  copper  ec_(salts)  \
# sample_code
# CA040CM0001           NaN    2.0  NaN      2.0   NaN     2.0         2.0
# CC176SA6046           NaN    2.0  NaN      NaN   NaN     2.0         2.0
# CD018PA0028           NaN    2.0  NaN      2.0   NaN     2.0         NaN
# CD018PA0031           NaN    2.0  NaN      2.0   NaN     2.0         NaN
# CD162AF0014           NaN    2.0  NaN      2.0   NaN     2.0         NaN
# ...                   ...    ...  ...      ...   ...     ...         ...
# CT042SA6302           NaN    NaN  NaN      NaN   2.0     NaN         NaN
# CT042SA6304           NaN    NaN  NaN      NaN   2.0     NaN         NaN
# CT240CM0009           NaN    2.0  NaN      2.0   NaN     2.0         2.0
# CW017SA22117          2.0    2.0  2.0      2.0   NaN     2.0         2.0
# I38-1-25SA0015        NaN    2.0  NaN      NaN   NaN     2.0         NaN
#
#                 exchangeable_acidity  iron  magnesium  manganese  \
# sample_code
# CA040CM0001                      NaN   2.0        2.0        2.0
# CC176SA6046                      NaN   2.0        2.0        2.0
# CD018PA0028                      NaN   2.0        2.0        2.0
# CD018PA0031                      NaN   2.0        2.0        2.0
# CD162AF0014                      NaN   2.0        2.0        2.0
# ...                              ...   ...        ...        ...
# CT042SA6302                      NaN   NaN        NaN        NaN
# CT042SA6304                      NaN   NaN        NaN        NaN
# CT240CM0009                      NaN   2.0        2.0        2.0
# CW017SA22117                     2.0   2.0        2.0        2.0
# I38-1-25SA0015                   NaN   2.0        NaN        2.0
#
#                 organic_carbon   ph  phosphorus  sand  silt  sodium  sulphur  \
# sample_code
# CA040CM0001                NaN  NaN         2.0   NaN   NaN     NaN      2.0
# CC176SA6046                2.0  2.0         2.0   NaN   NaN     2.0      2.0
# CD018PA0028                NaN  NaN         2.0   NaN   NaN     2.0      2.0
# CD018PA0031                NaN  NaN         2.0   NaN   NaN     2.0      2.0
# CD162AF0014                NaN  NaN         2.0   NaN   NaN     2.0      2.0
# ...                        ...  ...         ...   ...   ...     ...      ...
# CT042SA6302                2.0  NaN         NaN   2.0   2.0     NaN      NaN
# CT042SA6304                2.0  NaN         NaN   2.0   2.0     NaN      NaN
# CT240CM0009                NaN  2.0         2.0   NaN   NaN     2.0      2.0
# CW017SA22117               NaN  2.0         2.0   NaN   NaN     2.0      2.0
# I38-1-25SA0015             2.0  2.0         NaN   NaN   NaN     2.0      NaN
#
#                 total_nitrogen  zinc
# sample_code
# CA040CM0001                2.0   2.0
# CC176SA6046                2.0   2.0
# CD018PA0028                2.0   2.0
# CD018PA0031                2.0   2.0
# CD162AF0014                NaN   2.0
# ...                        ...   ...
# CT042SA6302                2.0   NaN
# CT042SA6304                2.0   NaN
# CT240CM0009                2.0   2.0
# CW017SA22117               NaN   2.0
# I38-1-25SA0015             2.0   2.0
#
# [149 rows x 20 columns]

# %%
# Handle Cook's outliers
cooks_outliers_df_2 = cooks_outliers_df.set_index("sample_code").isna()   

cooks_outliers_df_2.replace(True, np.nan, inplace=True)
cooks_outliers_df_2.replace(False, 3, inplace=True)

# %%
cooks_outliers_df_2
# Out:
#                  aluminium  boron  cec  calcium  clay  copper  ec_(salts)  \
# sample_code
# AGD103-32SA0001        NaN    NaN  NaN      3.0   NaN     NaN         NaN
# AGD103-33SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-34SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-34SA0002        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-37SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# ...                    ...    ...  ...      ...   ...     ...         ...
# I38-1-9SA0003          NaN    NaN  NaN      3.0   NaN     NaN         NaN
# I38-1-9SA0005          NaN    NaN  NaN      3.0   NaN     NaN         NaN
# I48-1-108SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# I48-1-109SA0001        NaN    NaN  NaN      3.0   NaN     NaN         NaN
# MN0001                 NaN    NaN  NaN      NaN   NaN     3.0         NaN
#
#                  exchangeable_acidity  iron  magnesium  manganese  \
# sample_code
# AGD103-32SA0001                   NaN   NaN        3.0        NaN
# AGD103-33SA0001                   NaN   NaN        3.0        NaN
# AGD103-34SA0001                   NaN   NaN        3.0        NaN
# AGD103-34SA0002                   NaN   NaN        3.0        NaN
# AGD103-37SA0001                   NaN   NaN        3.0        NaN
# ...                               ...   ...        ...        ...
# I38-1-9SA0003                     NaN   NaN        NaN        NaN
# I38-1-9SA0005                     NaN   NaN        NaN        NaN
# I48-1-108SA0001                   NaN   NaN        NaN        NaN
# I48-1-109SA0001                   NaN   NaN        NaN        NaN
# MN0001                            NaN   3.0        NaN        3.0
#
#                  organic_carbon  ph  phosphorus  sand  silt  sodium  sulphur  \
# sample_code
# AGD103-32SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# AGD103-33SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# AGD103-34SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# AGD103-34SA0002             NaN NaN         NaN   NaN   NaN     NaN      NaN
# AGD103-37SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# ...                         ...  ..         ...   ...   ...     ...      ...
# I38-1-9SA0003               NaN NaN         NaN   NaN   NaN     NaN      NaN
# I38-1-9SA0005               NaN NaN         NaN   NaN   NaN     NaN      NaN
# I48-1-108SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# I48-1-109SA0001             NaN NaN         NaN   NaN   NaN     NaN      NaN
# MN0001                      NaN NaN         NaN   NaN   NaN     NaN      NaN
#
#                  total_nitrogen  zinc
# sample_code
# AGD103-32SA0001             NaN   NaN
# AGD103-33SA0001             NaN   NaN
# AGD103-34SA0001             NaN   NaN
# AGD103-34SA0002             NaN   NaN
# AGD103-37SA0001             NaN   NaN
# ...                         ...   ...
# I38-1-9SA0003               NaN   NaN
# I38-1-9SA0005               NaN   NaN
# I48-1-108SA0001             NaN   NaN
# I48-1-109SA0001             NaN   NaN
# MN0001                      NaN   3.0
#
# [16431 rows x 20 columns]

# %%
# Handle Residual outliers
resid_outliers_df_2 = resid_outliers_df.set_index("sample_code").isna()   

resid_outliers_df_2.replace(True, np.nan, inplace=True)
resid_outliers_df_2.replace(False, 4, inplace=True)

# %%
resid_outliers_df_2
# Out:
#                   index  aluminium  boron  cec  calcium  clay  copper  \
# sample_code
# AGD207-408SA0706      4        NaN    4.0  4.0      4.0   NaN     4.0
# AGD207-410SA0001      4        NaN    4.0  4.0      4.0   NaN     4.0
# AGD207-410SA0002      4        NaN    4.0  4.0      4.0   NaN     4.0
# AGD207-411SA0001      4        NaN    4.0  4.0      4.0   NaN     4.0
# AGD207-411SA0002      4        NaN    4.0  4.0      4.0   NaN     4.0
# ...                 ...        ...    ...  ...      ...   ...     ...
# FA913-19SA0001        4        NaN    NaN  NaN      NaN   NaN     NaN
# FA913-21SA0001        4        NaN    NaN  4.0      NaN   NaN     NaN
# FA913-22SA0001        4        NaN    NaN  4.0      4.0   NaN     NaN
# I48-1-108SA0001       4        NaN    4.0  NaN      NaN   NaN     4.0
# I48-1-109SA0001       4        NaN    4.0  4.0      NaN   NaN     4.0
#
#                   ec_(salts)  exchangeable_acidity  iron  ...  manganese  \
# sample_code                                               ...
# AGD207-408SA0706         NaN                   NaN   NaN  ...        4.0
# AGD207-410SA0001         NaN                   NaN   NaN  ...        4.0
# AGD207-410SA0002         NaN                   NaN   NaN  ...        4.0
# AGD207-411SA0001         NaN                   NaN   NaN  ...        4.0
# AGD207-411SA0002         NaN                   NaN   NaN  ...        4.0
# ...                      ...                   ...   ...  ...        ...
# FA913-19SA0001           NaN                   NaN   NaN  ...        NaN
# FA913-21SA0001           NaN                   NaN   NaN  ...        NaN
# FA913-22SA0001           NaN                   NaN   NaN  ...        NaN
# I48-1-108SA0001          4.0                   NaN   4.0  ...        4.0
# I48-1-109SA0001          4.0                   NaN   4.0  ...        4.0
#
#                   organic_carbon   ph  phosphorus  sand  silt  sodium  \
# sample_code
# AGD207-408SA0706             4.0  4.0         4.0   NaN   NaN     4.0
# AGD207-410SA0001             4.0  4.0         4.0   NaN   NaN     4.0
# AGD207-410SA0002             4.0  4.0         4.0   NaN   NaN     4.0
# AGD207-411SA0001             4.0  4.0         4.0   NaN   NaN     4.0
# AGD207-411SA0002             4.0  4.0         4.0   NaN   NaN     4.0
# ...                          ...  ...         ...   ...   ...     ...
# FA913-19SA0001               NaN  4.0         NaN   NaN   NaN     NaN
# FA913-21SA0001               NaN  4.0         4.0   NaN   NaN     4.0
# FA913-22SA0001               NaN  4.0         4.0   NaN   NaN     4.0
# I48-1-108SA0001              NaN  4.0         4.0   NaN   NaN     4.0
# I48-1-109SA0001              NaN  4.0         NaN   NaN   NaN     4.0
#
#                   sulphur  total_nitrogen  zinc
# sample_code
# AGD207-408SA0706      4.0             4.0   4.0
# AGD207-410SA0001      4.0             4.0   4.0
# AGD207-410SA0002      4.0             4.0   4.0
# AGD207-411SA0001      4.0             4.0   4.0
# AGD207-411SA0002      4.0             4.0   4.0
# ...                   ...             ...   ...
# FA913-19SA0001        NaN             4.0   NaN
# FA913-21SA0001        NaN             4.0   NaN
# FA913-22SA0001        NaN             4.0   NaN
# I48-1-108SA0001       4.0             4.0   4.0
# I48-1-109SA0001       4.0             4.0   4.0
#
# [9140 rows x 21 columns]

# %%
wetchem_df
# Out:
#             sample_code aluminium boron   cec calcium clay copper  ec_(salts)  \
# 0       AGD103-32SA0001       NaN   NaN  33.9    3240  NaN    NaN         NaN
# 1       AGD103-33SA0001       NaN   NaN  45.0    4230  NaN    NaN         NaN
# 2       AGD103-34SA0001       NaN   NaN  49.0    5120  NaN    NaN         NaN
# 3       AGD103-34SA0002       NaN   NaN  47.9    5380  NaN    NaN         NaN
# 4       AGD103-36SA0001       NaN   NaN  18.2    1990  NaN    NaN         NaN
# ...                 ...       ...   ...   ...     ...  ...    ...         ...
# 106792  I48-1-108SA0001       NaN  0.37  43.8    8010  NaN   1.56       136.0
# 106793  I48-1-109SA0001       NaN  3.52  29.2    4990  NaN   0.75       460.0
# 106794  I48-1-111SA0001       NaN  0.45  13.0    1540  NaN   2.01        44.5
# 106795  I48-1-112SA0001       NaN  0.61  19.0    2060  NaN   6.34        34.2
# 106796           MN0001       NaN   NaN   NaN    21.3  NaN   1940         NaN
#
#        exchangeable_acidity  iron  ... manganese organic_carbon    ph  \
# 0                       NaN   NaN  ...       NaN            NaN  5.58
# 1                       NaN   NaN  ...       NaN            NaN  5.66
# 2                       NaN   NaN  ...       NaN            NaN  5.91
# 3                       NaN   NaN  ...       NaN            NaN  6.11
# 4                       NaN   NaN  ...       NaN            NaN  5.94
# ...                     ...   ...  ...       ...            ...   ...
# 106792                  NaN  56.4  ...      26.8            NaN  7.17
# 106793                  NaN  55.6  ...      17.6            NaN  7.48
# 106794                  NaN   291  ...       145            NaN  6.04
# 106795                  NaN   209  ...       121            NaN  5.83
# 106796                  NaN  8450  ...      3890            NaN   NaN
#
#        phosphorus sand silt sodium sulphur total_nitrogen  zinc
# 0            3.88  NaN  NaN    153     NaN           0.13   NaN
# 1            63.5  NaN  NaN   15.0     NaN           0.21   NaN
# 2            14.1  NaN  NaN   11.6     NaN           0.17   NaN
# 3            35.0  NaN  NaN   13.7     NaN           0.18   NaN
# 4            0.96  NaN  NaN   43.8     NaN           0.16   NaN
# ...           ...  ...  ...    ...     ...            ...   ...
# 106792        165  NaN  NaN   36.7    61.6           0.19  0.66
# 106793        NaN  NaN  NaN    101     183           0.81  0.50
# 106794       48.5  NaN  NaN   12.1    14.5          0.096  1.30
# 106795       67.6  NaN  NaN   11.9    19.2           0.16  4.31
# 106796       9.40  NaN  NaN    NaN    0.64            NaN  6130
#
# [106797 rows x 21 columns]

# %%
wetchem_df = wetchem_df[['sample_code']]

# %%
wetchem_df
# Out:
#             sample_code
# 0       AGD103-32SA0001
# 1       AGD103-33SA0001
# 2       AGD103-34SA0001
# 3       AGD103-34SA0002
# 4       AGD103-36SA0001
# ...                 ...
# 106792  I48-1-108SA0001
# 106793  I48-1-109SA0001
# 106794  I48-1-111SA0001
# 106795  I48-1-112SA0001
# 106796           MN0001
#
# [106797 rows x 1 columns]

# %%
outliers_df = pd.concat([hv_outliers_df_2, lv_outliers_df_2, cooks_outliers_df_2, resid_outliers_df_2], axis=0)

# %%
outliers_df = outliers_df.reset_index()
outliers_df
# Out:
#            sample_code  aluminium  boron  cec  calcium  clay  copper  \
# 0          CA040CM0001        NaN    1.0  NaN      1.0   NaN     1.0
# 1          CC176SA6046        NaN    1.0  NaN      NaN   NaN     1.0
# 2          CD018PA0028        NaN    1.0  NaN      1.0   NaN     1.0
# 3          CD018PA0031        NaN    1.0  NaN      1.0   NaN     1.0
# 4          CD162AF0014        NaN    1.0  NaN      1.0   NaN     1.0
# ...                ...        ...    ...  ...      ...   ...     ...
# 26901   FA913-19SA0001        NaN    NaN  NaN      NaN   NaN     NaN
# 26902   FA913-21SA0001        NaN    NaN  4.0      NaN   NaN     NaN
# 26903   FA913-22SA0001        NaN    NaN  4.0      4.0   NaN     NaN
# 26904  I48-1-108SA0001        NaN    4.0  NaN      NaN   NaN     4.0
# 26905  I48-1-109SA0001        NaN    4.0  4.0      NaN   NaN     4.0
#
#        ec_(salts)  exchangeable_acidity  iron  ...  organic_carbon   ph  \
# 0             1.0                   NaN   1.0  ...             NaN  NaN
# 1             1.0                   NaN   1.0  ...             1.0  1.0
# 2             NaN                   NaN   1.0  ...             NaN  NaN
# 3             NaN                   NaN   1.0  ...             NaN  NaN
# 4             NaN                   NaN   1.0  ...             NaN  NaN
# ...           ...                   ...   ...  ...             ...  ...
# 26901         NaN                   NaN   NaN  ...             NaN  4.0
# 26902         NaN                   NaN   NaN  ...             NaN  4.0
# 26903         NaN                   NaN   NaN  ...             NaN  4.0
# 26904         4.0                   NaN   4.0  ...             NaN  4.0
# 26905         4.0                   NaN   4.0  ...             NaN  4.0
#
#        phosphorus  sand  silt  sodium  sulphur  total_nitrogen  zinc  index
# 0             1.0   NaN   NaN     NaN      1.0             1.0   1.0    NaN
# 1             1.0   NaN   NaN     1.0      1.0             1.0   1.0    NaN
# 2             1.0   NaN   NaN     1.0      1.0             1.0   1.0    NaN
# 3             1.0   NaN   NaN     1.0      1.0             1.0   1.0    NaN
# 4             1.0   NaN   NaN     1.0      1.0             NaN   1.0    NaN
# ...           ...   ...   ...     ...      ...             ...   ...    ...
# 26901         NaN   NaN   NaN     NaN      NaN             4.0   NaN    4.0
# 26902         4.0   NaN   NaN     4.0      NaN             4.0   NaN    4.0
# 26903         4.0   NaN   NaN     4.0      NaN             4.0   NaN    4.0
# 26904         4.0   NaN   NaN     4.0      4.0             4.0   4.0    4.0
# 26905         NaN   NaN   NaN     4.0      4.0             4.0   4.0    4.0
#
# [26906 rows x 22 columns]

# %%
outliers_df = outliers_df.groupby("sample_code", sort=True).min()

# %%
outliers_df
# Out:
#                  aluminium  boron  cec  calcium  clay  copper  ec_(salts)  \
# sample_code
# AGD103-32SA0001        NaN    NaN  NaN      3.0   NaN     NaN         NaN
# AGD103-33SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-34SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-34SA0002        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# AGD103-37SA0001        NaN    NaN  3.0      3.0   NaN     NaN         NaN
# ...                    ...    ...  ...      ...   ...     ...         ...
# I38-1-9SA0003          NaN    NaN  NaN      3.0   NaN     NaN         NaN
# I38-1-9SA0005          NaN    NaN  NaN      3.0   NaN     NaN         NaN
# I48-1-108SA0001        NaN    4.0  3.0      3.0   NaN     4.0         4.0
# I48-1-109SA0001        NaN    4.0  4.0      3.0   NaN     4.0         4.0
# MN0001                 NaN    NaN  NaN      NaN   NaN     3.0         NaN
#
#                  exchangeable_acidity  iron  magnesium  ...  organic_carbon  \
# sample_code                                             ...
# AGD103-32SA0001                   NaN   NaN        3.0  ...             NaN
# AGD103-33SA0001                   NaN   NaN        3.0  ...             NaN
# AGD103-34SA0001                   NaN   NaN        3.0  ...             NaN
# AGD103-34SA0002                   NaN   NaN        3.0  ...             NaN
# AGD103-37SA0001                   NaN   NaN        3.0  ...             NaN
# ...                               ...   ...        ...  ...             ...
# I38-1-9SA0003                     NaN   NaN        NaN  ...             NaN
# I38-1-9SA0005                     NaN   NaN        NaN  ...             NaN
# I48-1-108SA0001                   NaN   4.0        4.0  ...             NaN
# I48-1-109SA0001                   NaN   4.0        4.0  ...             NaN
# MN0001                            NaN   3.0        NaN  ...             NaN
#
#                   ph  phosphorus  sand  silt  sodium  sulphur  total_nitrogen  \
# sample_code
# AGD103-32SA0001  NaN         NaN   NaN   NaN     NaN      NaN             NaN
# AGD103-33SA0001  NaN         NaN   NaN   NaN     NaN      NaN             NaN
# AGD103-34SA0001  NaN         NaN   NaN   NaN     NaN      NaN             NaN
# AGD103-34SA0002  NaN         NaN   NaN   NaN     NaN      NaN             NaN
# AGD103-37SA0001  NaN         NaN   NaN   NaN     NaN      NaN             NaN
# ...              ...         ...   ...   ...     ...      ...             ...
# I38-1-9SA0003    NaN         NaN   NaN   NaN     NaN      NaN             NaN
# I38-1-9SA0005    NaN         NaN   NaN   NaN     NaN      NaN             NaN
# I48-1-108SA0001  4.0         4.0   NaN   NaN     4.0      4.0             4.0
# I48-1-109SA0001  4.0         NaN   NaN   NaN     4.0      4.0             4.0
# MN0001           NaN         NaN   NaN   NaN     NaN      NaN             NaN
#
#                  zinc  index
# sample_code
# AGD103-32SA0001   NaN    NaN
# AGD103-33SA0001   NaN    NaN
# AGD103-34SA0001   NaN    NaN
# AGD103-34SA0002   NaN    NaN
# AGD103-37SA0001   NaN    NaN
# ...               ...    ...
# I38-1-9SA0003     NaN    NaN
# I38-1-9SA0005     NaN    NaN
# I48-1-108SA0001   4.0    4.0
# I48-1-109SA0001   4.0    4.0
# MN0001            3.0    NaN
#
# [23719 rows x 21 columns]

# %%
outliers_df = pd.merge(wetchem_df,outliers_df, on="sample_code", how="left")

# %%
outliers_df
# Out:
#             sample_code  aluminium  boron  cec  calcium  clay  copper  \
# 0       AGD103-32SA0001        NaN    NaN  NaN      3.0   NaN     NaN
# 1       AGD103-33SA0001        NaN    NaN  3.0      3.0   NaN     NaN
# 2       AGD103-34SA0001        NaN    NaN  3.0      3.0   NaN     NaN
# 3       AGD103-34SA0002        NaN    NaN  3.0      3.0   NaN     NaN
# 4       AGD103-36SA0001        NaN    NaN  NaN      NaN   NaN     NaN
# ...                 ...        ...    ...  ...      ...   ...     ...
# 106792  I48-1-108SA0001        NaN    4.0  3.0      3.0   NaN     4.0
# 106793  I48-1-109SA0001        NaN    4.0  4.0      3.0   NaN     4.0
# 106794  I48-1-111SA0001        NaN    NaN  NaN      NaN   NaN     NaN
# 106795  I48-1-112SA0001        NaN    NaN  NaN      NaN   NaN     NaN
# 106796           MN0001        NaN    NaN  NaN      NaN   NaN     3.0
#
#         ec_(salts)  exchangeable_acidity  iron  ...  organic_carbon   ph  \
# 0              NaN                   NaN   NaN  ...             NaN  NaN
# 1              NaN                   NaN   NaN  ...             NaN  NaN
# 2              NaN                   NaN   NaN  ...             NaN  NaN
# 3              NaN                   NaN   NaN  ...             NaN  NaN
# 4              NaN                   NaN   NaN  ...             NaN  NaN
# ...            ...                   ...   ...  ...             ...  ...
# 106792         4.0                   NaN   4.0  ...             NaN  4.0
# 106793         4.0                   NaN   4.0  ...             NaN  4.0
# 106794         NaN                   NaN   NaN  ...             NaN  NaN
# 106795         NaN                   NaN   NaN  ...             NaN  NaN
# 106796         NaN                   NaN   3.0  ...             NaN  NaN
#
#         phosphorus  sand  silt  sodium  sulphur  total_nitrogen  zinc  index
# 0              NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 1              NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 2              NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 3              NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 4              NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# ...            ...   ...   ...     ...      ...             ...   ...    ...
# 106792         4.0   NaN   NaN     4.0      4.0             4.0   4.0    4.0
# 106793         NaN   NaN   NaN     4.0      4.0             4.0   4.0    4.0
# 106794         NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 106795         NaN   NaN   NaN     NaN      NaN             NaN   NaN    NaN
# 106796         NaN   NaN   NaN     NaN      NaN             NaN   3.0    NaN
#
# [106797 rows x 22 columns]

# %%
outliers_df.to_excel("outputFiles/dl_outliers.xlsx")

# %%
wetchem_df = pd.read_csv("inputFiles/uncleaned_wetchem_20200916-20221107.csv")
# Out:
# C:\Users\Tsuma Thomas\AppData\Local\Temp\ipykernel_3080\3103285854.py:1: DtypeWarning: Columns (5,13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   wetchem_df = pd.read_csv("inputFiles/uncleaned_wetchem_20200916-20221107.csv")

# %%
wetchem_df = wetchem_df.rename(columns={"Unnamed: 0":"sample_code"})

# %%
wetchem_df = wetchem_df.set_index("sample_code")

# %%
wetchem_df
# Out:
#                 aluminium boron   cec calcium clay copper  ec_(salts)  \
# sample_code
# AGD103-32SA0001       NaN   NaN  33.9    3240  NaN    NaN         NaN
# AGD103-33SA0001       NaN   NaN  45.0    4230  NaN    NaN         NaN
# AGD103-34SA0001       NaN   NaN  49.0    5120  NaN    NaN         NaN
# AGD103-34SA0002       NaN   NaN  47.9    5380  NaN    NaN         NaN
# AGD103-36SA0001       NaN   NaN  18.2    1990  NaN    NaN         NaN
# ...                   ...   ...   ...     ...  ...    ...         ...
# I48-1-108SA0001       NaN  0.37  43.8    8010  NaN   1.56       136.0
# I48-1-109SA0001       NaN  3.52  29.2    4990  NaN   0.75       460.0
# I48-1-111SA0001       NaN  0.45  13.0    1540  NaN   2.01        44.5
# I48-1-112SA0001       NaN  0.61  19.0    2060  NaN   6.34        34.2
# MN0001                NaN   NaN   NaN    21.3  NaN   1940         NaN
#
#                 exchangeable_acidity  iron magnesium manganese  \
# sample_code
# AGD103-32SA0001                  NaN   NaN       595       NaN
# AGD103-33SA0001                  NaN   NaN       968       NaN
# AGD103-34SA0001                  NaN   NaN      1150       NaN
# AGD103-34SA0002                  NaN   NaN      1150       NaN
# AGD103-36SA0001                  NaN   NaN       391       NaN
# ...                              ...   ...       ...       ...
# I48-1-108SA0001                  NaN  56.4       193      26.8
# I48-1-109SA0001                  NaN  55.6       303      17.6
# I48-1-111SA0001                  NaN   291       263       145
# I48-1-112SA0001                  NaN   209       394       121
# MN0001                           NaN  8450      4.35      3890
#
#                  organic_carbon    ph phosphorus sand silt sodium sulphur  \
# sample_code
# AGD103-32SA0001             NaN  5.58       3.88  NaN  NaN    153     NaN
# AGD103-33SA0001             NaN  5.66       63.5  NaN  NaN   15.0     NaN
# AGD103-34SA0001             NaN  5.91       14.1  NaN  NaN   11.6     NaN
# AGD103-34SA0002             NaN  6.11       35.0  NaN  NaN   13.7     NaN
# AGD103-36SA0001             NaN  5.94       0.96  NaN  NaN   43.8     NaN
# ...                         ...   ...        ...  ...  ...    ...     ...
# I48-1-108SA0001             NaN  7.17        165  NaN  NaN   36.7    61.6
# I48-1-109SA0001             NaN  7.48        NaN  NaN  NaN    101     183
# I48-1-111SA0001             NaN  6.04       48.5  NaN  NaN   12.1    14.5
# I48-1-112SA0001             NaN  5.83       67.6  NaN  NaN   11.9    19.2
# MN0001                      NaN   NaN       9.40  NaN  NaN    NaN    0.64
#
#                 total_nitrogen  zinc
# sample_code
# AGD103-32SA0001           0.13   NaN
# AGD103-33SA0001           0.21   NaN
# AGD103-34SA0001           0.17   NaN
# AGD103-34SA0002           0.18   NaN
# AGD103-36SA0001           0.16   NaN
# ...                        ...   ...
# I48-1-108SA0001           0.19  0.66
# I48-1-109SA0001           0.81  0.50
# I48-1-111SA0001          0.096  1.30
# I48-1-112SA0001           0.16  4.31
# MN0001                     NaN  6130
#
# [106797 rows x 20 columns]

# %%
wetchem_df.to_csv("all_wetchem_transformed.csv")
