# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\python310\lib\site-packages (2.9.5)
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2
import pandas as pd

# %%
def get_db_cursor():
    username = "doadmin"
    password = 'yzmodwh2oh16iks6'
    host = 'db-postgresql-cl1-do-user-2276924-0.db.ondigitalocean.com'
    port = 25060
    database = 'MandatoryMetadata'
    schema = 'historical'

    conn = psycopg2.connect(host=host,database=database, user=username, password=password, port=port)
    cur = conn.cursor()
    cur.execute("SET search_path TO " + schema)

    return conn, cur

# %%
conn, cur = get_db_cursor()

# %%
conn
# Out:
# <connection object at 0x0000012EC8CF3DE0; dsn: 'user=doadmin password=xxx dbname=MandatoryMetadata host=db-postgresql-cl1-do-user-2276924-0.db.ondigitalocean.com port=25060', closed: 0>

# %%
# spectra = pd.read_sql("SELECT * FROM spectraldata", con=conn)
# spectra.to_csv("outputFiles/spectraldata.csv")
spectra = pd.read_csv("outputFiles/spectraldata.csv")

# %%
metadata = pd.read_sql("select * from mandatorymetadata m", con=conn)
# Out:
# C:\Users\Tsuma Thomas\AppData\Roaming\Python\Python310\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
chemicals = pd.read_sql("select * from chemical", con=conn)

# %%
metadata
# Out:
#       metadata_id  sample_code
# 0               1    ML-SS21-2
# 1               2    ML-SS21-2
# 2               3    ML-SS21-2
# 3               4    ML-SS21-2
# 4               5    ML-SS21-2
# ...           ...          ...
# 6901         6902  CF246SA0030
# 6902         6903  CF246SA0023
# 6903         6904  CF246SA0046
# 6904         6905  CF246SA0059
# 6905         6906  CF246SA0019
#
# [6906 rows x 2 columns]

# %%
metadata = metadata[['metadata_id','sample_code']]

# %%
chemicals = chemicals[['chemical_id','chemical_name']]
# Out:
#     chemical_id                    chemical_name  active model_id lims_name
# 0             1                        aluminium    True     None      None
# 1             2                            boron    True     None      None
# 2             3                          calcium    True     None      None
# 3             4                              cec    True     None      None
# 4             5                             clay    True     None      None
# 5             6                           copper    True     None      None
# 6             7                       ec_(salts)    True     None      None
# 7             8             exchangeable_acidity    True     None      None
# 8             9                             iron    True     None      None
# 9            10                        magnesium    True     None      None
# 10           11                        manganese    True     None      None
# 11           12                   organic_carbon    True     None      None
# 12           13                               ph    True     None      None
# 13           14                       phosphorus    True     None      None
# 14           15  phosphorus_sorption_index_(psi)    True     None      None
# 15           16                        potassium    True     None      None
# 16           17                             sand    True     None      None
# 17           18                             silt    True     None      None
# 18           19                           sodium    True     None      None
# 19           20                          sulphur    True     None      None
# 20           21                   total_nitrogen    True     None      None
# 21           22                             zinc    True     None      None

# %%
spectra = pd.merge(spectra,metadata,on="metadata_id",how="left")

# %%
spectra.to_csv("outputFiles/spectraldata.csv")

# %%
spectra
# Out:
#       Unnamed: 0  spectral_data_id  metadata_id datablock  \
# 0              0                45           13        AB
# 1              1                46           13        AB
# 2              2                74            1        AB
# 3              3                 5            1        AB
# 4              4                90           23        AB
# ...          ...               ...          ...       ...
# 2020        2020              1674          646        AB
# 2021        2021              1675          647        AB
# 2022        2022              1676          647        AB
# 2023        2023              1678          648        AB
# 2024        2024              1677          648        AB
#
#                                           opus_metadata  \
# 0     {'ABP': 1001299.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 1     {'ABP': 1001299.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 2                                                   NaN
# 3                                                   NaN
# 4     {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# ...                                                 ...
# 2020  {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 2021  {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 2022  {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 2023  {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
# 2024  {'ABP': 1001076.0, 'ADT': 0.0, 'APF': 'B3', 'A...
#
#                                    non_averaged_spectra  is_finalized  passed  \
# 0     {'522': [2.315193056887986, 2.3258604307668063...          True    True
# 1     {'522': [2.2528207439721912, 2.202161346749317...          True    True
# 2                                                   NaN         False   False
# 3                                                   NaN         False   False
# 4     {'522': [1.9819135501038987, 1.965563590137089...         False   False
# ...                                                 ...           ...     ...
# 2020  {'522': [2.393226217069065, 2.373137918822414,...          True    True
# 2021  {'522': [2.321204406764957, 2.2337616985740736...          True    True
# 2022  {'522': [2.235977673305072, 2.1950100299831035...          True    True
# 2023  {'522': [2.3074407139912645, 2.275902644954108...          True    True
# 2024  {'522': [2.388035565030344, 2.3692977775997788...          True    True
#
#       is_active  in_models  model_dataset_type  averaged  \
# 0          True        NaN                 NaN     False
# 1          True        NaN                 NaN     False
# 2         False        NaN                 NaN      True
# 3         False        NaN                 NaN      True
# 4         False        NaN                 NaN     False
# ...         ...        ...                 ...       ...
# 2020       True        NaN                 NaN     False
# 2021       True        NaN                 NaN     False
# 2022       True        NaN                 NaN     False
# 2023       True        NaN                 NaN     False
# 2024       True        NaN                 NaN     False
#
#                                        averaged_spectra            timestamp  \
# 0                                                   NaN  2023-01-24 14:04:43
# 1                                                   NaN  2023-01-24 14:04:43
# 2     {'521': [2.270869655047864, 2.2656960429803803...  2023-01-27 19:29:20
# 3     {'521': [2.270869655047864, 2.2656960429803803...  2023-01-23 13:27:13
# 4                                                   NaN  2023-01-27 20:21:18
# ...                                                 ...                  ...
# 2020                                                NaN  2023-02-13 09:57:22
# 2021                                                NaN  2023-02-13 09:57:22
# 2022                                                NaN  2023-02-13 09:57:22
# 2023                                                NaN  2023-02-13 09:57:22
# 2024                                                NaN  2023-02-13 09:57:22
#
#          sample_code
# 0     FA419-45SA0002
# 1     FA419-45SA0002
# 2          ML-SS21-2
# 3          ML-SS21-2
# 4           ISE958-1
# ...              ...
# 2020     CI014SA7234
# 2021     CI014SA7114
# 2022     CI014SA7114
# 2023     CI014SA6911
# 2024     CI014SA6911
#
# [2025 rows x 15 columns]

# %%
aver_spectra = spectra.loc[(spectra['averaged'] == True) & (spectra['is_finalized'] == True) & (spectra['passed'] == True) & (spectra['is_active'] == True)]

# %%
aver_spectra
# Out:
#      Unnamed: 0  spectral_data_id  metadata_id datablock opus_metadata  \
# 13           13               128           31        AB           NaN
# 33           33                63           17        AB           NaN
# 35           35                71           19        AB           NaN
# 82           82                51           11        AB           NaN
# 83           83                52           12        AB           NaN
# ..          ...               ...          ...       ...           ...
# 956         956               965          294        AB           NaN
# 959         959               966          295        AB           NaN
# 962         962               967          296        AB           NaN
# 965         965               968          297        AB           NaN
# 968         968               969          298        AB           NaN
#
#     non_averaged_spectra  is_finalized  passed  is_active  in_models  \
# 13                   NaN          True    True       True        NaN
# 33                   NaN          True    True       True        NaN
# 35                   NaN          True    True       True        NaN
# 82                   NaN          True    True       True        NaN
# 83                   NaN          True    True       True        NaN
# ..                   ...           ...     ...        ...        ...
# 956                  NaN          True    True       True        NaN
# 959                  NaN          True    True       True        NaN
# 962                  NaN          True    True       True        NaN
# 965                  NaN          True    True       True        NaN
# 968                  NaN          True    True       True        NaN
#
#      model_dataset_type  averaged  \
# 13                  NaN      True
# 33                  NaN      True
# 35                  NaN      True
# 82                  NaN      True
# 83                  NaN      True
# ..                  ...       ...
# 956                 NaN      True
# 959                 NaN      True
# 962                 NaN      True
# 965                 NaN      True
# 968                 NaN      True
#
#                                       averaged_spectra            timestamp
# 13   {'522': [2.3244656573818396, 2.300363936880086...  2023-02-01 08:59:36
# 33   {'522': [2.3243741634120374, 2.307540485180485...  2023-01-25 07:05:33
# 35   {'522': [2.2630152586026915, 2.290110779246487...  2023-01-25 07:36:28
# 82   {'522': [2.154119577513004, 2.1818486646526885...  2023-01-24 14:05:43
# 83   {'522': [2.163048776013803, 2.154486397031147,...  2023-01-24 14:05:43
# ..                                                 ...                  ...
# 956  {'522': [2.5759881562328175, 2.518430902142690...  2023-02-08 06:48:06
# 959  {'522': [2.2600618534801002, 2.278567590699612...  2023-02-08 06:48:06
# 962  {'522': [2.2296622939407986, 2.278561230392871...  2023-02-08 06:48:06
# 965  {'522': [2.2908693509229217, 2.286768733501291...  2023-02-08 06:48:06
# 968  {'522': [2.264492650388667, 2.279136683831879,...  2023-02-08 06:48:06
#
# [210 rows x 14 columns]

# %%
aver_spectra = pd.merge(aver_spectra, metadata, on='metadata_id', how='left')

# %%
aver_spectra
# Out:
#      Unnamed: 0  spectral_data_id  metadata_id datablock opus_metadata  \
# 0            13               128           31        AB           NaN
# 1            33                63           17        AB           NaN
# 2            35                71           19        AB           NaN
# 3            82                51           11        AB           NaN
# 4            83                52           12        AB           NaN
# ..          ...               ...          ...       ...           ...
# 205         956               965          294        AB           NaN
# 206         959               966          295        AB           NaN
# 207         962               967          296        AB           NaN
# 208         965               968          297        AB           NaN
# 209         968               969          298        AB           NaN
#
#     non_averaged_spectra  is_finalized  passed  is_active  in_models  \
# 0                    NaN          True    True       True        NaN
# 1                    NaN          True    True       True        NaN
# 2                    NaN          True    True       True        NaN
# 3                    NaN          True    True       True        NaN
# 4                    NaN          True    True       True        NaN
# ..                   ...           ...     ...        ...        ...
# 205                  NaN          True    True       True        NaN
# 206                  NaN          True    True       True        NaN
# 207                  NaN          True    True       True        NaN
# 208                  NaN          True    True       True        NaN
# 209                  NaN          True    True       True        NaN
#
#      model_dataset_type  averaged  \
# 0                   NaN      True
# 1                   NaN      True
# 2                   NaN      True
# 3                   NaN      True
# 4                   NaN      True
# ..                  ...       ...
# 205                 NaN      True
# 206                 NaN      True
# 207                 NaN      True
# 208                 NaN      True
# 209                 NaN      True
#
#                                       averaged_spectra            timestamp  \
# 0    {'522': [2.3244656573818396, 2.300363936880086...  2023-02-01 08:59:36
# 1    {'522': [2.3243741634120374, 2.307540485180485...  2023-01-25 07:05:33
# 2    {'522': [2.2630152586026915, 2.290110779246487...  2023-01-25 07:36:28
# 3    {'522': [2.154119577513004, 2.1818486646526885...  2023-01-24 14:05:43
# 4    {'522': [2.163048776013803, 2.154486397031147,...  2023-01-24 14:05:43
# ..                                                 ...                  ...
# 205  {'522': [2.5759881562328175, 2.518430902142690...  2023-02-08 06:48:06
# 206  {'522': [2.2600618534801002, 2.278567590699612...  2023-02-08 06:48:06
# 207  {'522': [2.2296622939407986, 2.278561230392871...  2023-02-08 06:48:06
# 208  {'522': [2.2908693509229217, 2.286768733501291...  2023-02-08 06:48:06
# 209  {'522': [2.264492650388667, 2.279136683831879,...  2023-02-08 06:48:06
#
#         sample_code
# 0       CO064SA0543
# 1       CS006SA0042
# 2    FA419-51SA0016
# 3    FA419-43SA0001
# 4    FA419-46SA0003
# ..              ...
# 205     CI014SA6999
# 206     CI014SA7005
# 207     CI014SA6983
# 208     CI014SA7000
# 209     CI014SA6982
#
# [210 rows x 15 columns]

# %%
len(aver_spectra['sample_code'].unique())
# Out:
# 210

# %%
aver_spectra.to_csv("outputFiles/averaged_spectra_samples.csv")

# %%
predictions = pd.read_sql("select * from prediction p", con=conn)
# Out:
# C:\Users\Tsuma Thomas\AppData\Roaming\Python\Python310\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
predictions = pd.merge(predictions, chemicals, on="chemical_id",how="left")[['sample_code','chemical_name','prediction']]

# %%
predictions.to_csv("outputFiles/predictions.csv")

# %%
aver_spectra.to_csv("averaged_spectra_samples.csv")
